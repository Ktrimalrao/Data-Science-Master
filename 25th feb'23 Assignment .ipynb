# %%
"""***************************** 25th feb'23 Assignment *****************************"""
# Out:
# "***************************** 25th feb'23 Assignment *****************************"

# %%
import pandas as pd
course_name = ['Data Science','Machine Learning', 'Big Data', 'Data Engineer']
duration = [2,3,6,4]
df = pd.DataFrame(data = {'course_name' : course_name, 'duration' : duration})
df
# Out:
#         course_name  duration
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6
# 3     Data Engineer         4

# %%
"""Q1. Write a code to print the data present in the second row of the dataframe, df."""

#df.iloc[1]
df.iloc[1:2,[0,1]]
# Out:
#         course_name  duration
# 1  Machine Learning         3

# %%
"""Q2. What is the difference between the functions loc and iloc in pandas.DataFrame?"""

Ans.
    loc: This function is primarily label-based. It is used for selecting rows and columns using labels or boolean arrays. 
        When using loc, you provide the row and column labels explicitly. It includes both the start and end labels in the selection.
        
    iloc: This function is primarily integer-based. It is used for selecting rows and columns using integer positions. 
        When using iloc, you provide the row and column positions explicitly.
        It includes the start position but excludes the end position in the selection.

# %%
df.iloc[0:2,[0,1]]
# Out:
#         course_name  duration
# 0      Data Science         2
# 1  Machine Learning         3

# %%
df.loc[0:2,['course_name','duration']]
# Out:
#         course_name  duration
# 0      Data Science         2
# 1  Machine Learning         3
# 2          Big Data         6

# %%
"""Q3. Reindex the given dataframe using a variable, reindex = [3,0,1,2] and store it in the variable, new_df
        then find the output for both new_df.loc[2] and new_df.iloc[2]. """

import pandas as pd
import numpy as np
columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']
indices = [1,2,3,4,5,6]
#Creating a dataframe:
df1 = pd.DataFrame(np.random.rand(6,6), columns = columns, index = indices)
df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.634003  0.931992  0.342404  0.780323  0.452971  0.236658
# 2  0.776093  0.992131  0.710612  0.145935  0.917493  0.614535
# 3  0.816910  0.362202  0.369803  0.009996  0.863639  0.505728
# 4  0.763008  0.382200  0.281693  0.554513  0.544638  0.937803
# 5  0.399777  0.951930  0.882157  0.531906  0.886259  0.641462
# 6  0.729929  0.207912  0.112466  0.119816  0.598513  0.758098

# %%
new_df = df1.reindex([3,0,1,2])
new_df
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 3  0.816910  0.362202  0.369803  0.009996  0.863639  0.505728
# 0       NaN       NaN       NaN       NaN       NaN       NaN
# 1  0.634003  0.931992  0.342404  0.780323  0.452971  0.236658
# 2  0.776093  0.992131  0.710612  0.145935  0.917493  0.614535

# %%
new_df.loc[2]
# Out:
# column_1    0.776093
# column_2    0.992131
# column_3    0.710612
# column_4    0.145935
# column_5    0.917493
# column_6    0.614535
# Name: 2, dtype: float64

# %%
new_df.iloc[2]
# Out:
# column_1    0.634003
# column_2    0.931992
# column_3    0.342404
# column_4    0.780323
# column_5    0.452971
# column_6    0.236658
# Name: 1, dtype: float64

# %%
"""Q4. Write a code to find the following statistical measurements for the above dataframe df1:
        (i) mean of each and every column present in the dataframe.
        (ii) standard deviation of column, ‘column_2’"""

df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.634003  0.931992  0.342404  0.780323  0.452971  0.236658
# 2  0.776093  0.992131  0.710612  0.145935  0.917493  0.614535
# 3  0.816910  0.362202  0.369803  0.009996  0.863639  0.505728
# 4  0.763008  0.382200  0.281693  0.554513  0.544638  0.937803
# 5  0.399777  0.951930  0.882157  0.531906  0.886259  0.641462
# 6  0.729929  0.207912  0.112466  0.119816  0.598513  0.758098

# %%
df1.mean()
# Out:
# column_1    0.686620
# column_2    0.638061
# column_3    0.449856
# column_4    0.357082
# column_5    0.710586
# column_6    0.615714
# dtype: float64

# %%
df1.std()
# Out:
# column_1    0.153453
# column_2    0.356894
# column_3    0.288077
# column_4    0.306602
# column_5    0.201773
# column_6    0.236837
# dtype: float64

# %%
df1['column_2'].std()
# Out:
# 0.35689375850618094

# %%
"""Q5. Replace the data present in the second row of column, ‘column_2’ by a string variable then find the
        mean of column, column_2.
        If you are getting errors in executing it then explain why.
    [Hint: To replace the data use df1.loc[] and equate this to string data of your choice.]"""

df1['column_2'] =['.931992','0.992131','0.362202','0.382200','0.951930','0.207912']

# %%
df1['column_2'].mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/nanops.py:1630, in _ensure_numeric(x)
#    1629 try:
# -> 1630     x = float(x)
#    1631 except (TypeError, ValueError):
#    1632     # e.g. "1+1j" or "foo"
#
# ValueError: could not convert string to float: '.9319920.9921310.3622020.3822000.9519300.207912'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/pandas/core/nanops.py:1634, in _ensure_numeric(x)
#    1633 try:
# -> 1634     x = complex(x)
#    1635 except ValueError as err:
#    1636     # e.g. "foo"
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
    * Incorrect column name: Make sure that 'column_2' is the correct name of the column you want to modify and calculate the mean of.
    * Data type incompatibility: If the column 'column_2' contains non-numeric values, calculating the mean will result in an error.
      Ensure that the column contains numeric values for the mean calculation to work.
# Out:
#   Cell In[71], line 1
#     * Incorrect column name: Make sure that 'column_2' is the correct name of the column you want to modify and calculate the mean of.
#                 ^
# SyntaxError: invalid syntax

# %%
"""Q6. What do you understand about the windows function in pandas and list the types of windows
            functions?"""

Ans.
    Windows functions in pandas operate on a specified range of rows and perform calculations based on that range.
    The range can be defined by a fixed number of preceding or following rows or can be dynamic based on a time period or another columns values.
# Out:
#   Cell In[72], line 4
#     Ans.
#         ^
# SyntaxError: invalid syntax

# %%
df_14 = pd.DataFrame({'ABC':[5,4,6,7,3,8,7,3,9,2]})
df_14['ABC'].rolling(window = 1).mean()
# Out:
# 0    5.0
# 1    4.0
# 2    6.0
# 3    7.0
# 4    3.0
# 5    8.0
# 6    7.0
# 7    3.0
# 8    9.0
# 9    2.0
# Name: ABC, dtype: float64

# %%
df_14['ABC'].rolling(window = 2).max()
# Out:
# 0    NaN
# 1    5.0
# 2    6.0
# 3    7.0
# 4    7.0
# 5    8.0
# 6    8.0
# 7    7.0
# 8    9.0
# 9    9.0
# Name: ABC, dtype: float64

# %%
.
rolling.mean(): Calculates the mean of values in the window.
rolling.sum(): Calculates the sum of values in the window.
rolling.min(): Finds the minimum value in the window.
rolling.max(): Finds the maximum value in the window.
rolling.std(): Calculates the standard deviation of values in the window.
rolling.count(): Counts the non-null values in the window.
# Out:
#   Cell In[75], line 1
#     .
#     ^
# SyntaxError: invalid syntax

# %%
"""Q7. Write a code to print only the current month and year at the time of answering this question.
        [Hint: Use pandas.datetime function]"""

date_1 = pd.date_range(start='2023-06-01',end='2023-06-7')
date_1
# Out:
# DatetimeIndex(['2023-06-01', '2023-06-02', '2023-06-03', '2023-06-04',
#                '2023-06-05', '2023-06-06', '2023-06-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
Date1 = pd.DataFrame({"Date":date_1})
Date1['Update Date'] = pd.to_datetime(Date1['Date'])
Date1
# Out:
#         Date Update Date
# 0 2023-06-01  2023-06-01
# 1 2023-06-02  2023-06-02
# 2 2023-06-03  2023-06-03
# 3 2023-06-04  2023-06-04
# 4 2023-06-05  2023-06-05
# 5 2023-06-06  2023-06-06
# 6 2023-06-07  2023-06-07

# %%
Date1['Month'] = Date1['Update Date'].dt.month

# %%
Date1['Year'] = Date1['Update Date'].dt.year

# %%
Date1
# Out:
#         Date Update Date  Month  Year
# 0 2023-06-01  2023-06-01      6  2023
# 1 2023-06-02  2023-06-02      6  2023
# 2 2023-06-03  2023-06-03      6  2023
# 3 2023-06-04  2023-06-04      6  2023
# 4 2023-06-05  2023-06-05      6  2023
# 5 2023-06-06  2023-06-06      6  2023
# 6 2023-06-07  2023-06-07      6  2023

# %%
"""Q8. Write a Python program that takes in two dates as input (in the format YYYY-MM-DD) and
        calculates the difference between them in days, hours, and minutes using Pandas time delta. The
        program should prompt the user to enter the dates and display the result."""

DATE_1 = input("Enter Starting Date --> (in the format YYYY-MM-DD) : ")
y1 = int(input("Enter Starting Date Timing in ['Hour']"))
z1 = int(input("Enter Starting Date Timing in ['Minute']"))
DATE_2 = input("Enter Ending Date --> (in the format YYYY-MM-DD) : ")
y2 = int(input("Enter Ending Date Timing in ['Hour']"))
z2 = int(input("Enter Ending Date Timing in ['Minute']"))

date_1 = pd.to_datetime(DATE_1)
date_2 =pd.to_datetime(DATE_2)
time_1 = pd.Timedelta(hours=y1,minutes=z1)
time_2 = pd.Timedelta(hours=y2,minutes=z2)

diff_date = date_2 - date_1
diff_time = time_2 - time_1
print('Difference between these days:',diff_date,diff_time)
# Out:
# Enter Starting Date --> (in the format YYYY-MM-DD) :  2023-10-01
# Enter Starting Date Timing in ['Hour'] 10
# Enter Starting Date Timing in ['Minute'] 30
# Enter Ending Date --> (in the format YYYY-MM-DD) :  2023-12-01
# Enter Ending Date Timing in ['Hour'] 12
# Enter Ending Date Timing in ['Minute'] 45
# Difference between these days: 61 days 00:00:00 0 days 02:15:00

# %%
"""Q9. Write a Python program that reads a CSV file containing categorical data and converts a specified
        column to a categorical data type. The program should prompt the user to enter the file path, column
        name, and category order, and then display the sorted data."""


cat = pd.read_csv("service_2.csv")
cat
# Out:
#      Name  Age  Gender
# 0   Alice   25  Female
# 1     Bob   30    Male
# 2  Claire   27  Female

# %%
catagory = input('Enter category order: ')
column = input('Enter the column name: ')
cat['Gender'].astype('category')

if catagory=='ascending':
    cat=cat.sort_values(by = column, ascending= True)
elif catagory=='descending':
    cat=cat.sort_values(by = column, ascending= False)        # Enter category order:  ascending
                                                              # Enter the column name:  Age
else:
    print("Invalid order")
cat
# Out:
# Enter category order:  ascending
# Enter the column name:  Age
#      Name  Age  Gender
# 0   Alice   25  Female
# 2  Claire   27  Female
# 1     Bob   30    Male

# %%
"""Q10. Write a Python program that reads a CSV file containing sales data for different products and
        visualizes the data using a stacked bar chart to show the sales of each product category over time. The
        program should prompt the user to enter the file path and display the chart."""
import csv
data_33 = [      
    ['Date', 'No. of Product-1 Sale','No. of Product-2 Sale'],
    ['2023-01-01', 25,23],
    ['2023-01-02', 38,12],
    ['2023-01-03', 41,11],
    ['2023-01-04', 29,21],
    ['2023-01-05', 34,9],
    ['2023-01-06', 47,6],
    ['2023-01-07', 36,10],
    ['2023-01-08', 22,17],
    ['2023-01-09', 31,14],
    ['2023-01-10', 39,9]]

with open("service_4.csv",'w') as f :
    write_file = csv.writer(f)
    for i in data_33:
        write_file.writerow(i)

# %%
chat = pd.read_csv("service_4.csv")
chat
# Out:
#          Date  No. of Product-1 Sale  No. of Product-2 Sale
# 0  2023-01-01                     25                     23
# 1  2023-01-02                     38                     12
# 2  2023-01-03                     41                     11
# 3  2023-01-04                     29                     21
# 4  2023-01-05                     34                      9
# 5  2023-01-06                     47                      6
# 6  2023-01-07                     36                     10
# 7  2023-01-08                     22                     17
# 8  2023-01-09                     31                     14
# 9  2023-01-10                     39                      9

# %%
chat = chat.set_index('Date')
chat.plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
""""Q11. You are given a CSV file containing student data that includes the student ID and their test score. Write
        a Python program that reads the CSV file, calculates the mean, median, and mode of the test scores, and
        displays the results in a table.
        The program should do the followingM
        I Prompt the user to enter the file path of the CSV file containing the student dataR
        I Read the CSV file into a Pandas DataFrameR
        I Calculate the mean, median, and mode of the test scores using Pandas toolsR
        I Display the mean, median, and mode in a table.
"""

csv_filename = input("Enter your .csv file : ")
df_101 = pd.read_csv(csv_filename)
# filename = service_3.csv
df_101
# Out:
# Enter your .csv file :  service_3.csv
#     Registration No.  Roll No.               Name  Course      Year  \
# 0            2023001         1           John Doe  B.tech  2nd year
# 1            2023002         2         Jane Smith  B.tech  2nd year
# 2            2023003         3      David Johnson  B.tech  2nd year
# 3            2023004         4        Emily Davis  B.tech  2nd year
# 4            2023005         5     Michael Wilson  B.tech  2nd year
# 5            2023006         6     Sarah Anderson  B.tech  2nd year
# 6            2023007         7    Christopher Lee  B.tech  2nd year
# 7            2023008         8    Olivia Martinez  B.tech  2nd year
# 8            2023009         9     William Taylor  B.tech  2nd year
# 9            2023010        10       Sophia Brown  B.tech  2nd year
# 10           2023011        11   Alexander Miller  B.tech  2nd year
# 11           2023012        12         Ava Wilson  B.tech  2nd year
# ...

# %%
mean101 = df_101['External Marks'].mean()
median101 = df_101['External Marks'].median()
mode10 = df_101['External Marks'].mode()

pd.DataFrame({'Statistic':['Mean','Median','Mode'],
                'Value':[mean101,median101,mode10]})
# Out:
#   Statistic                                              Value
# 0      Mean                                          44.766667
# 1    Median                                               45.0
# 2      Mode  0    45
# 1    46
# Name: External Marks, dtype: i...
